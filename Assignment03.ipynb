# %% [markdown]
# <a href="https://colab.research.google.com/github/DrFlour/MAT494/blob/main/Assignment03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

diabetes_X = diabetes_X[:, np.newaxis, 6]

diabetes_X_train = diabetes_X[:8]
diabetes_X_test = diabetes_X[8:]
diabetes_y_train = diabetes_y[:8]
diabetes_y_test = diabetes_y[8:]

regr = linear_model.LinearRegression()
regr.fit(diabetes_X_train, diabetes_y_train)
diabetes_y_pred = regr.predict(diabetes_X_test)

print('Coefficients: \n', regr.coef_)
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))

plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=5)
plt.scatter(diabetes_X_test, diabetes_y_test,  color='green')
plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients:
#  [-907.04407184]
# Coefficient of determination: 0.04
# Mean squared error: 5759.73
